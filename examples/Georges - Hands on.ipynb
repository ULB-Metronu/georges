# %% [markdown]
# # Adding your local Georges to your path

# %%
import sys
sys.path.append('/Users/chernals/Downloads/')
import georges

# %% [markdown]
# # Importing libraries

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot([1,2], [2,4])

# %%
import georges
import georges.madx

# %%
georges.physics.kinematics(range=32)
# Out:
# {'beta': 0.59219057901310057,
#  'brho': 2.3000819451857275,
#  'energy': 226.12911179644985,
#  'gamma': 1.2410059046872013,
#  'momentum': 689.54741674333184,
#  'range': 32}

# %%
IBA_OPTICS_PATH = "/Users/chernals/reps/IBA-Optics/beamlines"

bl = georges.BeamlineBuilder(path=IBA_OPTICS_PATH, prefix='generic/P1') \
                         .add_from_file('cgtr') \
                         .build()
bl.line
# Out:
#                  TYPE  AT_CENTER  LENGTH     ANGLE   APERTYPE       APERTURE  \
# NAME
# COLL           MARKER    0.00001   0.000       NaN        NaN            NaN
# T1GX           MARKER    0.19200   0.000       NaN        NaN            NaN
# T2GY           MARKER    0.42200   0.000       NaN        NaN            NaN
# Q1G        QUADRUPOLE    1.06000   0.297       NaN     CIRCLE        0.03175
# Q2G        QUADRUPOLE    1.66000   0.297       NaN     CIRCLE        0.03175
# P1G            MARKER    1.99000   0.000       NaN        NaN            NaN
# DIVSLITSX       SLITS    2.04000   0.060       NaN  RECTANGLE            NaN
# DIVSLITSY       SLITS    2.11000   0.060       NaN  RECTANGLE            NaN
# B1G             SBEND    3.06000   1.050  0.698132  RECTANGLE  0.058, 0.0258
# Q3G        QUADRUPOLE    3.99000   0.290       NaN     CIRCLE        0.03175
# P2G            MARKER    4.28000   0.000       NaN        NaN            NaN
# ...
