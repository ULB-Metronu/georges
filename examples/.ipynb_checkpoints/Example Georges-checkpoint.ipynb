# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
import os
sys.path.append("/Users/chernals/cernbox/Work/packages")
import pandas as pd
import matplotlib.pyplot as plt

# %%
import georges
PATH = "/Users/chernals/Dropbox/IBA/Work/IBA-Optics/beamlines"

### Defining a default context
brho = georges.physics.momentum_to_brho(georges.physics.energy_to_momentum(177.5))
context = {
        'PARTICLE': 'PROTON',
        'PC': georges.physics.energy_to_momentum(177.5),
        'BETAX'   : 0.0846155,
        'BETAY'   : 0.0846155,
        'ALPHAX': 0.0,
        'ALPHAY': 0.0,
        'DELTAP': 0.0,
        'DPP': 0.5e-2,
        'MOMENTUM_SLITS_OPENING' : 1.015,
        'DIVERGENCE_SLITS_OPENING_X' : 1.015,
        'DIVERGENCE_SLITS_OPENING_Y' : 1.015,
        'N_TRACKING': 5000,
        'EMITX': 14.3e-6,
        'EMITY': 14.3e-6,
        'KQ1E': 4.187,
        'KQ2E'   : -8.777,
        'KQ3E'   : 6.231,
        'KQ47E'  : -4.678,
        'KQ56E'  : 4.064,
        'KQ8E'   : 5.421,
        'KQ9E'   : -6.153,
        'KQ10E'  : 6.165,
}

# %%
#bdsim = georges.bdsim.BDSim(bdsim='/Users/chernals/bdsim-build/bdsim', path=PATH)
bl = georges.Beamline(['ess'], survey=True, path=PATH, prefix='generic', elements='elements')
#georges.madx.survey(line=bl, context=context)
bl_twiss = georges.madx.twiss(line=bl, context=context, debug=True)
b = georges.Beam(energy=200).from_5d_multigaussian_distribution(5,
                                                   XRMS=0.01,
                                                   PXRMS=0.001,
                                                   YRMS=0.01,
                                                   PYRMS=0.001,
                                                   DPPRMS=0.00)
#georges.madx.track(line=bl, context=context, beam=b)
# Out:
# ESS: SEQUENCE, L=21.50573219177883, REFER=CENTER;
# Q1E: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, K1:=KQ1E, AT=0.1475;
# Q2E: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, K1:=KQ2E, AT=0.7754965761053156;
# Q3E: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, K1:=KQ3E, AT=1.2084974422707315;
# B1E: RBEND, ANGLE=0.5235987755982988, APERTYPE=RECTANGLE, E1=0.0, E2=0.0, FINT=0.5, HGAP=0.023, THICK=True, TILT=0.0, L=0.7770459458562767, APERTURE=0.035, 0.035, AT=2.5772027571115648;
# B2E: RBEND, ANGLE=0.5235987755982988, APERTYPE=RECTANGLE, E1=0.0, E2=0.0, FINT=0.5, HGAP=0.023, THICK=True, TILT=0.0, L=0.7770459458562767, APERTURE=0.035, 0.035, AT=3.7695027571115642;
# Q4E: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, K1:=KQ47E, AT=4.601137150452546;
# Q5E: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, K1:=QK56E, AT=5.0331432347847;
# Q6E: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, AT=5.6872010042515875;
# Q7E: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, AT=6.119198428317982;
# B3E: RBEND, ANGLE=0.5235987755982988, APERTYPE=RECTANGLE, E1=0.0, E2=0.0, FINT=0.5, HGAP=0.023, THICK=True, TILT=0.0, L=0.7770459458562767, APERTURE=0.035, 0.035, AT=6.951115853593435;
# B4E: RBEND, ANGLE=0.5235987755982988, APERTYPE=RECTANGLE, E1=0.0, E2=0.0, FINT=0.5, HGAP=0.023, THICK=True, TILT=0.0, L=0.7770459458562767, APERTURE=0.035, 0.035, AT=8.133088117269702;
# Q8E: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, K1:=KQ8E, AT=9.056863694296776;
# Q9E: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, K1:=KQ9E, AT=9.830863694296776;
# Q10E: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, K1:=KQ10E, AT=10.510863694296775;
# B1B1: RBEND, ANGLE=0.5235987755982988, APERTYPE=RECTANGLE, E1=0.0, E2=0.0, FINT=0.5, HGAP=0.023, THICK=True, TILT=0.0, L=0.7770459458562767, APERTURE=0.035, 0.035, AT=12.090168117269704;
# Q1B1: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, AT=12.925010061241018;
# Q2B1: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, AT=13.435007501332633;
# Q3B1: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, AT=13.945004941424246;
# B2B1: RBEND, ANGLE=0.5235987755982988, APERTYPE=RECTANGLE, E1=0.0, E2=0.0, FINT=0.5, HGAP=0.023, THICK=True, TILT=0.0, L=0.7770459458562767, APERTURE=0.035, 0.035, AT=14.773493931362669;
# Q1F1: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, AT=15.540290998281355;
# Q2F1: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, AT=16.106693779347975;
# Q3F1: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, AT=16.6266909994367;
# B1F1: RBEND, ANGLE=-0.5235987755982988, APERTYPE=RECTANGLE, E1=0.0, E2=0.0, FINT=0.5, HGAP=0.023, THICK=True, TILT=0.0, L=0.7770459458562767, APERTURE=0.035, 0.035, AT=19.488713667721843;
# Q4F1: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, AT=20.83823510063312;
# Q5F1: QUADRUPOLE, APERTYPE=CIRCLE, L=0.295, APERTURE=0.035, AT=21.35823219177883;
# ENDSEQUENCE;
# KQ1E:=4.187;
# KQ2E:=-8.777;
# KQ3E:=6.231;
# KQ47E:=-4.678;
# QK56E:=0.0;
# KQ8E:=5.421;
# KQ9E:=-6.153;
# KQ10E:=6.165;
# BEAM, PARTICLE=PROTON, PC=0.603815211799;
# USE, SEQUENCE=ESS;
# TWISS, BETX=0.0846155,ALFX=0.0,MUX=0.0,BETY=0.0846155,ALFY=0.0,MUY=0.0,DX=0.0,DPX=0.0,DY=0.0,DPY=0.0,X=0.0,PX=0.0,Y=0.0,PY=0.0,T=0.0,PT=0.0,DELTAP=0.0,FILE=twiss.outx,centre=True;
# STOP;

# %%
bdsim.attach(bl_survey)
bdsim.run({})
#bdsim.print_input()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-daf02a952333> in <module>()
# ----> 1 bdsim.attach(bl_survey)
#       2 bdsim.run({})
#       3 #bdsim.print_input()
#
# NameError: name 'bdsim' is not defined

# %%
from georges.plotting import *
with plt.style.context('word'):
    fig = plt.figure(1)

    ax1 = fig.add_subplot(111)
    prepare(ax1, bl)
    aperture(ax1, bl)
    twiss(ax1, bl_twiss, context)
    #track(ax1, bl, b)

# %%
import numpy as np
data = pd.read_csv("/Users/chernals/Ranges.csv", index_col='range')
ranges = pd.Series(pd.to_numeric(data.columns))
data.index
#ranges = data.columns.is_monotonic_decreasing
#ranges
# Out:
# Index(['DEGRADER', 'GROUP3', 'Q1E', 'Q2E', 'Q3E', 'Q47E', 'Q56E', 'Q8E', 'Q9E',
#        'Q10E', 'Q1B1', 'Q2B1', 'Q3B1', 'Q1F1', 'Q2F1', 'B1234E', 'B12B1',
#        'TRB34E', 'T2E', 'TRB2B1', 'T1F1', 'B1F1', 'Q3F1', 'Q4F1', 'SL1E',
#        'SL2E', 'SL3E'],
#       dtype='object', name='range')

# %%
# Out:
# 'D'

# %%
data.query("index=='GROUP3'").interpolate()#.values
# Out:
#           32.54     31.5     30.5     29.5     28.5     27.5     26.5  \
# range
# GROUP3  1.58967  1.57222  1.55514  1.53777  1.52007  1.50204  1.48364
#
#            25.5     24.5     23.5    ...        15.5     14.5     13.5  \
# range                                ...
# GROUP3  1.46486  1.44566  1.42602    ...     1.24788  1.22206  1.19514
#
#            12.5     11.5     10.5      9.5      8.5     7.72       4.1
# range
# GROUP3  1.16697  1.13737  1.10613  1.07297  1.03751  1.00795  0.837952
#
# [1 rows x 27 columns]

# %%
import subprocess as sub
p = sub.Popen(["/Users/chernals/bdsim-build/bdsim --file=/Users/chernals/Desktop/bdsim.gmad"],
                      
                      shell=True
                      )

# %%
from subprocess import call
call(["/Users/chernals/bdsim-build/bdsim", "--file=/Users/chernals/Desktop/bdsim.gmad"])
# Out:
# 1
