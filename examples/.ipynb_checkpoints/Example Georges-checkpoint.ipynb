# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from georges import *
PATH = "/Users/chernals/Dropbox/IBA/Work/IBA-Optics"

# %%
b = Beam(energy=200).from_5d_multigaussian_distribution(20,
                                               XRMS=0.01,
                                               PXRMS=0.001,
                                               YRMS=0.01,
                                               PYRMS=0.001,
                                               DPPRMS=0.00)

context = {
    'PARTICLE': 'PROTON',
    #'PC': energy_to_momentum(177.5),
    'BETAX'   : 0.0846155,
    'BETAY'   : 0.0846155,
    'ALPHAX': 0.0,
    'ALPHAY': 0.0,
    'DELTAP': 0.0,
    'DPP': 0.5e-2,
    'IQ1G': 2.741, # K1 IQ1G
    'MOMENTUM_SLITS_OPENING' : 0.015,
    'DIVERGENCE_SLITS_OPENING_X' : 0.015,
    'DIVERGENCE_SLITS_OPENING_Y' : 0.015,
    'N_TRACKING': 5000,
    'EMITX': 14.3e-6,
    'EMITY': 14.3e-6,
    'BETAREL': 0.5,
}

bl = Beamline('cgtr', beam=b, elements='beamlines/elements', path=PATH, prefix='beamlines/generic')
# If using a direct path
#bl = Beamline('cgtr', beam=b, elements='elements', path='path/to/files')

# %%
bl.line
# Out:
#                 TYPE  AT_CENTER CIRCUIT       CLASS    LENGTH   APERTYPE  \
# NAME
# DEG           MARKER   0.000000     NaN      MARKER       NaN        NaN
# Q1G        CGTR_QUAD   1.142187    IQ1G  QUADRUPOLE  0.284375     CIRCLE
# Q2G        CGTR_QUAD   1.742188    IQ2G  QUADRUPOLE  0.284375     CIRCLE
# B1G         CGTR_B40   3.138876     NaN       SBEND       NaN  RECTANGLE
# Q3G        CGTR_QUAD   4.071875    IQ3G  QUADRUPOLE  0.284375     CIRCLE
# Q4G        CGTR_QUAD   4.687875    IQ4G  QUADRUPOLE  0.284375     CIRCLE
# Q5G   CGTR_QUAD_LONG   5.411875    IQ5G  QUADRUPOLE  0.495000     CIRCLE
# Q6G        CGTR_QUAD   6.136875    IQ6G  QUADRUPOLE  0.284375     CIRCLE
# Q7G        CGTR_QUAD   6.786875    IQ7G  QUADRUPOLE  0.284375     CIRCLE
# B2G         CGTR_B70   8.383783     NaN       SBEND       NaN  RECTANGLE
# B3G         CGTR_B60  11.057839     NaN       SBEND       NaN  RECTANGLE
# ISO           MARKER  12.996668     NaN      MARKER       NaN        NaN
#
#            APERTURE  TILT     RHO     ANGLE    ...     E1  E2   HGAP  THICK  \
# NAME                                           ...
# DEG             NaN   NaN     NaN       NaN    ...    NaN NaN    NaN    NaN
# Q1G           0.035   NaN     NaN       NaN    ...    NaN NaN    NaN    NaN
# Q2G           0.035   NaN     NaN       NaN    ...    NaN NaN    NaN    NaN
# B1G    [0.04, 0.02]   0.0  1500.0  0.698132    ...    NaN NaN  0.023   True
# Q3G           0.035   NaN     NaN       NaN    ...    NaN NaN    NaN    NaN
# Q4G           0.035   NaN     NaN       NaN    ...    NaN NaN    NaN    NaN
# Q5G           0.035   NaN     NaN       NaN    ...    NaN NaN    NaN    NaN
# Q6G           0.035   NaN     NaN       NaN    ...    NaN NaN    NaN    NaN
# Q7G           0.035   NaN     NaN       NaN    ...    NaN NaN    NaN    NaN
# B2G   [0.030,0.030]   0.0  1500.0  1.221730    ...    NaN NaN  0.023   True
# B3G            0.01   0.0  1600.0  1.047198    ...    NaN NaN  0.023   True
# ISO             NaN   NaN     NaN       NaN    ...    NaN NaN    NaN    NaN
#
#      PLUG CHAMBER   AT_ENTRY    AT_EXIT  ORBIT_LENGTH  PHYSICAL
# NAME
# DEG   NaN     NaN   0.000000   0.000000      0.000000      True
# Q1G    K1   0.005   1.000000   1.284375      0.284375      True
# Q2G    K1   0.005   1.600000   1.884375      0.284375      True
# B1G   NaN   0.005   2.615278   3.662475      1.047198      True
# Q3G    K1   0.005   3.929688   4.214063      0.284375      True
# Q4G    K1   0.005   4.545688   4.830063      0.284375      True
# Q5G    K1   0.005   5.164375   5.659375      0.495000      True
# Q6G    K1   0.005   5.994687   6.279062      0.284375      True
# Q7G    K1   0.005   6.644687   6.929062      0.284375      True
# B2G   NaN   0.005   7.467485   9.300081      1.832596      True
# B3G   NaN   0.005  10.220081  11.895597      1.675516      True
# ISO   NaN     NaN  12.996668  12.996668      0.000000      True
#
# [12 rows x 21 columns]

# %%
bl.twiss
bl.track;

# %%
bl.print_madx_input
# Out:
# CGTR: SEQUENCE, L=12.99666779, REFER=CENTER;
# DEG: MARKER, , L=0.0, AT=0.0;
# Q1G: QUADRUPOLE, APERTYPE=CIRCLE, L=0.284375, APERTURE=0.035, K1:=IQ1G, AT=1.1421875;
# Q2G: QUADRUPOLE, APERTYPE=CIRCLE, L=0.284375, APERTURE=0.035, K1:=IQ2G, AT=1.7421875;
# B1G: SBEND, ANGLE=0.6981317007977318, APERTYPE=RECTANGLE, FINT=0.5, HGAP=0.023, THICK=True, TILT=0.0, L=1.0471975511965976, APERTURE=0.04, 0.02, AT=3.1388762760000004;
# Q3G: QUADRUPOLE, APERTYPE=CIRCLE, L=0.284375, APERTURE=0.035, K1:=IQ3G, AT=4.071875051;
# Q4G: QUADRUPOLE, APERTYPE=CIRCLE, L=0.284375, APERTURE=0.035, K1:=IQ4G, AT=4.687875051000001;
# Q5G: QUADRUPOLE, APERTYPE=CIRCLE, L=0.495, APERTURE=0.035, K1:=IQ5G, AT=5.411875051;
# Q6G: QUADRUPOLE, APERTYPE=CIRCLE, L=0.284375, APERTURE=0.035, K1:=IQ6G, AT=6.136874871;
# Q7G: QUADRUPOLE, APERTYPE=CIRCLE, L=0.284375, APERTURE=0.035, K1:=IQ7G, AT=6.786874991;
# B2G: SBEND, ANGLE=1.2217304763960306, APERTYPE=RECTANGLE, FINT=0.5, HGAP=0.023, THICK=True, TILT=0.0, L=1.832595714594046, APERTURE=0.030,0.030, AT=8.383782848;
# B3G: SBEND, ANGLE=1.0471975511965976, APERTYPE=RECTANGLE, FINT=0.5, HGAP=0.023, THICK=True, TILT=0.0, L=1.6755160819145563, APERTURE=0.01, AT=11.05783875;
# ISO: MARKER, , L=0.0, AT=12.99666779;
#
#
#
#
#
#
#
#
#
#
#
#
#
# ENDSEQUENCE;
# IQ1G:=0.0;
# IQ2G:=0.0;
# IQ3G:=0.0;
# IQ4G:=0.0;
# IQ5G:=0.0;
# IQ6G:=0.0;
# IQ7G:=0.0;
# BEAM, PARTICLE=proton, PC=0.64444456705;
# USE, SEQUENCE=CGTR;
# SELECT, FLAG=makethin, CLASS=quadrupole, THICK=false, SLICE=3;
# SELECT, FLAG=makethin, CLASS=rbend, THICK=false, SLICE=1;
# MAKETHIN, sequence=CGTR, style=TEAPOT;
# USE, SEQUENCE=CGTR;
# TRACK,DELTAP=0.0,ONEPASS=true,APERTURE=true,DUMP=true,ONETABLE=true,FILE=tracking.outx;
# START, X=-0.0018761287343871148, PX=2.6839828186122215e-05, Y=-0.002306628376551837, PY=0.00130768993706771, T=0.0, PT=0.0;
# START, X=0.009568487812063885, PX=-0.00039436217372546846, Y=-0.0055134959608679245, PY=0.0008209293632738112, T=0.0, PT=0.0;
# START, X=0.008088405681332901, PX=0.0010869536462465206, Y=-0.012086840256442305, PY=0.0017210161318493504, T=0.0, PT=0.0;
# START, X=0.013257437017237762, PX=0.0004593664103053056, Y=-0.00457700976772062, PY=0.001049187347523437, T=0.0, PT=0.0;
# START, X=0.007081521839504687, PX=-0.0009506870675091227, Y=0.0214305188578533, PY=-0.0003465679177062381, T=0.0, PT=0.0;
# START, X=0.00207802416046207, PX=0.0017695833621087743, Y=-0.013354535635171067, PY=0.001654988829414782, T=0.0, PT=0.0;
# START, X=-0.009277710932755175, PX=-0.0012493662704888987, Y=-0.006460156790540856, PY=0.0005096960499753293, T=0.0, PT=0.0;
# START, X=0.006743842815027962, PX=0.000654557246690404, Y=-0.015199762455529592, PY=0.00044846563859758757, T=0.0, PT=0.0;
# START, X=-0.00029006385245955007, PX=-0.000323012102967095, Y=0.011058003257285938, PY=0.0008976748336597509, T=0.0, PT=0.0;
# START, X=0.00492213698628748, PX=-0.0004181913946346644, Y=0.0028798076618180525, PY=-0.0005366679353209491, T=0.0, PT=0.0;
# START, X=-0.010755490710040823, PX=0.001251566888738212, Y=0.003237026022833732, PY=0.0007860578492466367, T=0.0, PT=0.0;
# START, X=0.012977628836616253, PX=0.0008232417827665852, Y=0.0037234134705515886, PY=0.0017990303891627082, T=0.0, PT=0.0;
# START, X=0.0032347351295168294, PX=-0.000603451392517004, Y=-0.0169402590450345, PY=-0.001051501914189615, T=0.0, PT=0.0;
# START, X=-0.006515955839778153, PX=0.001618398903965287, Y=-0.00717282122360251, PY=0.0013269995894747751, T=0.0, PT=0.0;
# START, X=0.0035975865829762873, PX=0.0013399611534931227, Y=0.004312934800893135, PY=-0.00014870027852765462, T=0.0, PT=0.0;
# START, X=-0.006584456334025539, PX=-0.00045903127396190074, Y=0.011112433932580452, PY=-0.0014862053724335929, T=0.0, PT=0.0;
# START, X=-0.00194295117778104, PX=-0.00014634488482017803, Y=-0.001924377993570896, PY=-0.0005774550647291562, T=0.0, PT=0.0;
# START, X=-0.001568016415045906, PX=0.0008398794549493747, Y=-0.0183374592026878, PY=-0.0010851465452063804, T=0.0, PT=0.0;
# START, X=-0.0098677452840033, PX=-0.0017407940236954383, Y=-0.003718245096008748, PY=0.000963948962233714, T=0.0, PT=0.0;
# START, X=-0.009120907275791318, PX=0.00020386107987173125, Y=-0.0058801591551382905, PY=-0.0004304751968768833, T=0.0, PT=0.0;
# OBSERVE, PLACE=DEG;
# OBSERVE, PLACE=Q1G;
# OBSERVE, PLACE=Q2G;
# OBSERVE, PLACE=B1G;
# OBSERVE, PLACE=Q3G;
# OBSERVE, PLACE=Q4G;
# OBSERVE, PLACE=Q5G;
# OBSERVE, PLACE=Q6G;
# OBSERVE, PLACE=Q7G;
# OBSERVE, PLACE=B2G;
# OBSERVE, PLACE=B3G;
# OBSERVE, PLACE=CGTR$START;
# OBSERVE, PLACE=DRIFT_0;
# OBSERVE, PLACE=DRIFT_1;
# OBSERVE, PLACE=DRIFT_2;
# OBSERVE, PLACE=DRIFT_3;
# OBSERVE, PLACE=DRIFT_4;
# OBSERVE, PLACE=DRIFT_5;
# OBSERVE, PLACE=DRIFT_6;
# OBSERVE, PLACE=DRIFT_7;
# OBSERVE, PLACE=DRIFT_8;
# OBSERVE, PLACE=DRIFT_9;
# OBSERVE, PLACE=DRIFT_10;
# OBSERVE, PLACE=CGTR$END;
# RUN, TURNS=1, MAXAPER=0.1,1.0,0.1,0.1,100.0,10.0;
# ENDTRACK;
# STOP;

# %%
with plt.style.context('word'):
    fig = plt.figure(1)
    
    ax1 = fig.add_subplot(111)
    prepare(ax1, bl)
    aperture(ax1, bl)
    #twiss(ax1, bl, context)
    track(ax1, bl, context)
# Out:
# NAME
# DEG           <georges.beam.Beam object at 0x105d722e8>
# CGTR$START                                          NaN
# DRIFT_0                                             NaN
# Q1G           <georges.beam.Beam object at 0x105d72358>
# DRIFT_1                                             NaN
# Q2G           <georges.beam.Beam object at 0x105dd1438>
# DRIFT_2                                             NaN
# B1G           <georges.beam.Beam object at 0x105dd1470>
# DRIFT_3                                             NaN
# Q3G           <georges.beam.Beam object at 0x105dd12b0>
# DRIFT_4                                             NaN
# Q4G           <georges.beam.Beam object at 0x105dd16a0>
# DRIFT_5                                             NaN
# Q5G           <georges.beam.Beam object at 0x105dd1630>
# DRIFT_6                                             NaN
# Q6G           <georges.beam.Beam object at 0x105dd19e8>
# DRIFT_7                                             NaN
# Q7G           <georges.beam.Beam object at 0x105dd17b8>
# DRIFT_8                                             NaN
# B2G           <georges.beam.Beam object at 0x105dd1748>
# DRIFT_9                                             NaN
# B3G           <georges.beam.Beam object at 0x105dd1240>
# DRIFT_10                                            NaN
# ISO           <georges.beam.Beam object at 0x105dd1a58>
# CGTR$END                                            NaN
# Name: BEAM, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-380c8fa585aa> in <module>()
#       6     aperture(ax1, bl)
#       7     #twiss(ax1, bl, context)
# ----> 8     track(ax1, bl, context)
#
# /Users/chernals/.ipython/georges/plotting/tracking.py in track(ax, bl, plane)
#       5     bl = bl.line
#       6     print(bl['BEAM'])
# ----> 7     filled_plot(ax, bl.index, 1000 * bl['BEAM'].apply(lambda x: x.std()))
#       8     pass
#       9
#
# /usr/local/lib/python3.5/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62658)()
#
# /Users/chernals/.ipython/georges/plotting/tracking.py in <lambda>(x)
#       5     bl = bl.line
#       6     print(bl['BEAM'])
# ----> 7     filled_plot(ax, bl.index, 1000 * bl['BEAM'].apply(lambda x: x.std()))
#       8     pass
#       9
#
# /Users/chernals/.ipython/georges/beam.py in std(self)
#      88     def std(self):
#      89         """Return a dataframe containing the second order moments of each dimensions."""
# ---> 90         return self.__distribution.dropna().std()
#      91
#      92     @property
#
# /usr/local/lib/python3.5/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    3011                 agg_obj = self.take(indices, axis=agg_axis)
#    3012
# -> 3013             count = agg_obj.count(axis=agg_axis)
#    3014
#    3015             if thresh is not None:
#
# /usr/local/lib/python3.5/site-packages/pandas/core/frame.py in count(self, axis, level, numeric_only)
#    4711             else:
#    4712                 counts = notnull(frame.values).sum(axis=axis)
# -> 4713                 result = Series(counts, index=frame._get_agg_axis(axis))
#    4714
#    4715         return result.astype('int64')
#
# /usr/local/lib/python3.5/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     227                                        raise_cast_failure=True)
#     228
# --> 229                 data = SingleBlockManager(data, index, fastpath=True)
#     230
#     231         generic.NDFrame.__init__(self, data, fastpath=True)
#
# /usr/local/lib/python3.5/site-packages/pandas/core/internals.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    3815         if not isinstance(block, Block):
#    3816             block = make_block(block, placement=slice(0, len(axis)), ndim=1,
# -> 3817                                fastpath=True)
#    3818
#    3819         self.blocks = [block]
#
# /usr/local/lib/python3.5/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    2516                      placement=placement, dtype=dtype)
#    2517
# -> 2518     return klass(values, ndim=ndim, fastpath=fastpath, placement=placement)
#    2519
#    2520 # TODO: flexible with index=None and/or items=None
#
# /usr/local/lib/python3.5/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim, fastpath)
#      88             raise ValueError('Wrong number of items passed %d, placement '
#      89                              'implies %d' % (len(self.values),
# ---> 90                                              len(self.mgr_locs)))
#      91
#      92     @property
#
# ValueError: Wrong number of items passed 40, placement implies 34
